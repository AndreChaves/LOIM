# %%
import main as main
import susc_gg as sc
# %matplotlib inline
import matplotlib
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10
#matplotlib.use('Qt4Agg')
#matplotlib.rcParams['backend.qt4']='PySide'
#import matplotlib as mpl
from matplotlib.backends.backend_agg import FigureCanvasAgg as fc

import matplotlib.pyplot as plt
import numpy as np


#print x.susc
#fig = plt.Figure()
#for j in range( x.n_q):
#    plt.plot(x.freq.real,x.susc.real[:,j])
#   plt.plot(x2.freq.real,x2.susc.real[:,j],'*')
#    z=1.-1./(q[j]**2)*x.susc.real[:,j]
#    plt.plot(x.freq.real,x.freq.real-x.freq.real,'k')
#    plt.plot(x.freq.real,z)
#    plt.plot(x2.freq.real,x2.susc.real[:,j],'*')
#   plt.plot(x.freq.real,x.susc.real[:,j])

#plt.plot(freq,freq)
#plt.ylim(-1.,1.)
#qvec=np.linspace(0.0001,0.05,num=50)
#pot=lambda x: 1/x
#pl=x.Plasmon(q_vec=qvec,Potential=pot)
#plt.plot(qvec,pl.real)
#wvec=np.sqrt(0.3*qvec/3.14)
#plt.plot(qvec,wvec,'r')
#plt.plot(x.freq,pl)

# %%
freq=np.linspace(0.,1.2,num=1000)
q=np.array([0.000001,0.15,0.3])
mu=0.3
p1=main.sc.grap_parameters(Ef=mu,gamma=3.7E-3,lam=0.,m=0.)
x=main.Susceptibility(sc.graphene_susc,freq,q,p1)
x2=main.Susceptibility(sc.graphene_susc0,freq,q,p1)
cond=x.Conductivity()
mermim=x.Mermim()
mermim2=x2.Mermim()
z=x.Conductivity(Mermim_option=True)
z2=x.Conductivity(Mermim_option=False)
fig=plt.figure()
ax1=fig.add_subplot(311)
ax1.plot(x.freq.real/mu,4.*z[:,0].real,'r',label='Mermim')
#plt.plot(x.freq.real,z.imag,'b')
ax1.plot(x.freq.real/mu,4.*z2[:,0].real,'b',label='Lindhard')
plt.xlabel(r'$\omega/\omega_F$',fontsize=52)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
#plt.ylabel(r'$\mathcal{R}\sigma/\sigma_0$',fontsize=52)
plt.legend(prop={'size':32},loc=1)
ax1.annotate(r'$q=0$',xy=(2,60.),xytext=(2.,60.),fontsize=32)
    #plt.ylim(-1.,10.)
#plt.plot(x.freq.real,z2.imag,'k')
ax2=fig.add_subplot(312)
ax2.plot(x.freq.real/mu,4.*z[:,1].real,'r')
ax2.plot(x.freq.real/mu,4.*z2[:,1].real,'b')
ax2.annotate(r'$q=0.5k_F$',xy=(2,10.),xytext=(2.,10.),fontsize=32)

plt.xlabel(r'$\omega/\omega_F$',fontsize=52)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.ylabel(r'$\mathcal{R}\sigma/\sigma_0$',fontsize=52)
#plt.ylim(-1.,9.)
ax3=fig.add_subplot(313)
ax3.plot(x.freq.real/mu,4.*z[:,2].real,'r')
ax3.plot(x.freq.real/mu,4.*z2[:,2].real,'b')
ax3.annotate(r'$q=k_F$',xy=(2,8.),xytext=(2.,8.),fontsize=32)

#plt.ylim(-1.,8.)
#plt.plot(x.freq.real,z2.real,'b')
#plt.ylim(-1.,1.)
#plt.xlim(0.,0.2)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlabel(r'$\omega/\omega_F$',fontsize=52)
#plt.ylabel(r'$R\sigma/\sigma_0$',fontsize=52)
plt.savefig('gE6real')

# %%
fig=plt.figure()
ax1=fig.add_subplot(311)
ax1.plot(x.freq.real/mu,4.*z[:,0].real,'r',label='Mermim')
#plt.plot(x.freq.real,z.imag,'b')
ax1.plot(x.freq.real/mu,4.*z2[:,0].real,'b',label='Lindhard')
plt.xlabel(r'$\omega/\omega_F$',fontsize=52)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(prop={'size':32},loc=1)

#plt.ylabel(r'$R\sigma/\sigma_0$',fontsize=52)
ax1.annotate(r'$q=0.$',xy=(2,60.),xytext=(2.,60.),fontsize=32)

#plt.ylim(-1.,10.)
#plt.plot(x.freq.real,z2.imag,'k')
ax2=fig.add_subplot(312)
ax2.plot(x.freq.real/mu,4.*z[:,1].imag,'r')
ax2.plot(x.freq.real/mu,4.*z2[:,1].imag,'b')
plt.ylabel(r'$\mathcal{I}\sigma/\sigma_0$',fontsize=52)
ax2.annotate(r'$q=0.5k_F$',xy=(2,8.),xytext=(2.,8.),fontsize=32)

plt.xlabel(r'$\omega/\omega_F$',fontsize=52)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
#plt.ylabel(r'$R\sigma/\sigma_0$',fontsize=52)

#plt.ylim(-1.,9.)
ax3=fig.add_subplot(313)
ax3.plot(x.freq.real/mu,4.*z[:,2].imag,'r')
ax3.plot(x.freq.real/mu,4.*z2[:,2].imag,'b')
ax3.annotate(r'$q=k_F$',xy=(2,6.),xytext=(2.,6.),fontsize=32)
#plt.ylim(-1.,8.)
#plt.plot(x.freq.real,z2.real,'b')
#plt.ylim(-1.,1.)
#plt.xlim(0.,0.2)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlabel(r'$\omega/\omega_F$',fontsize=52)
#plt.ylabel(r'$R\sigma/\sigma_0$',fontsize=52)
plt.savefig('gE6imag')

# %%
print (sc.graphene_susc0(1.,2.,p1))

# %%
qvec=[.000001]
mu2=0.5
freq_vec=np.linspace(0.,3.*mu2,num=1000)
g1=260.E-6
p2=main.sc.grap_parameters(Ef=mu2,gamma=g1,lam=0.,m=0.)
p3=main.sc.grap_parameters(Ef=mu2,gamma=0.,lam=0.,m=0.)
x2=main.Susceptibility(sc.graphene_susc0,freq_vec,qvec,p2)
x3=main.Susceptibility(sc.graphene_susc,freq_vec,qvec,p2)
#qvec=np.linspace(0.00001,0.4,num=100)

cond2=x2.Conductivity()*4.
cond2m=x2.Conductivity(Mermim_option=True)*4.
cond3=x3.Conductivity()*4.
cond3m=x3.Conductivity(Mermim_option=True)*4.
#plt.plot(x2.freq.real,cond2m.real,'b*')
plt.plot(x3.freq.real/mu2,cond3m.real,'r',linewidth=2.,label='Real Part')

#plt.plot(x2.freq.real,cond2m.real,'rs')
#plt.plot(x2.freq.real,cond2m.imag,'go')
plt.plot(x3.freq.real/mu2,cond3m.imag,'g',linewidth=2.,label='Imaginary Part')
cpl=sc.graf_cond(freq_vec,p2)
#plt.plot(freq_vec,cpl.real,'c')
#plt.plot(freq_vec,cpl.imag,'y')
#plt.plot(x2.freq.real,cond2m.imag,'k^')
#plt.plot(qvec,x2.susc.real[0,:])
#plt.plot(qvec,x2.susc.imag[0,:])
plt.xlim(0.,3.)
#plt.ylim(-4.*mu2/g1*2.,100.)
#plt.plot(x3.freq.real,cond3.real)
#plt.plot(x3.freq.real,cond3m.real)
plt.ylim(-3.,10.)#4.1*mu2/3.14/g1)
plt.legend(prop={'size':36},loc=1)
plt.tick_params(axis='x', labelsize=30)
plt.tick_params(axis='y', labelsize=30)
plt.xlabel(r'$\omega/\omega_F$',fontsize=52)
plt.ylabel(r'$\sigma/\sigma_0$',fontsize=52)
plt.savefig('test')

# %%
N=1000
x1= 2./N*np.arange(N+1)
y1=2.-x1
x2=4./N*np.arange(N+1)
y2=x2	
y3=x2+2.
y4=x2-2.
fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(1,1,1)
ax.plot(x1,y1,'k',linewidth=2.)
ax.plot(x2,y2,'k',linewidth=2.)
ax.plot(x2,y3,'k',linewidth=2.)
ax.plot(x2,y4,'k',linewidth=2.)
qplot=np.zeros(len(freq))+q[0]
ax.plot(qplot/mu,freq/mu,'r--',linewidth=2.)
qplot=np.zeros(len(freq))+q[1]
ax.plot(qplot/mu,freq/mu,'r--',linewidth=2.)
qplot=np.zeros(len(freq))+q[2]
ax.plot(qplot/mu,freq/mu,'r--',linewidth=2.)
plt.ylim(0.,3.5)
plt.xlim(-.01,3.5)
plt.xticks([2.])
plt.yticks([2.])
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelsize=32) # labels along the bottom edge are off
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    right='off',      # ticks along the bottom edge are off
    left='off',         # ticks along the top edge are off
    labelsize=32) # labels along the bottom edge are off
ax.annotate('1A',xy=(1,0.2),xytext=(0.7	,0.3),fontsize=32)
ax.annotate('2A',xy=(1,0.5),xytext=(1.8	,1.),fontsize=32)
ax.annotate('3A',xy=(1,0.5),xytext=(2.8	,0.3),fontsize=32)
ax.annotate('1B',xy=(1,0.5),xytext=(0.2	,1.),fontsize=32)
ax.annotate('2B',xy=(1,0.2),xytext=(0.7	,2.),fontsize=32)
ax.annotate('3B',xy=(1,0.5),xytext=(0.2	,3.),fontsize=32)
ax.set_xlabel(r'$q/k_F $ ',fontsize=32)
ax.set_ylabel(r'$\omega/\omega_F$ ',fontsize=32)
fig.savefig('1a.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-ee58bceee03c> in <module>()
#      14 qplot=np.zeros(len(freq))+q[0]
#      15 ax.plot(qplot/mu,freq/mu,'r--',linewidth=2.)
# ---> 16 qplot=np.zeros(len(freq))+q[1]
#      17 ax.plot(qplot/mu,freq/mu,'r--',linewidth=2.)
#      18 qplot=np.zeros(len(freq))+q[2]
#
# IndexError: index out of bounds

# %%
from functools import partial
#Plasmon Dispersion
freq=np.linspace(0.,0.3,num=1000)
q=np.array([1.2])
mu=0.1
p1=main.sc.grap_parameters(Ef=mu,gamma=2.E-3,lam=0.,m=0.)
xp=main.Susceptibility(sc.graphene_susc,freq,q,p1)
q_vec=np.linspace(1.E-3,2.1*mu,num=200)
fsconst=1./(137.035)
peq=2.*np.pi*fsconst*300.
print(xp.Mermim_Formula(qin=1.,fin=2.),xp.formula(1.,2.))
z=partial(main.Susceptibility.Mermim_Formula,self=xp)
print(z(qin=1,fin=2))
plas2=xp.Plasmon(q_vec,Potential=lambda x: peq/x,Mermim_option=False,step=1.E-5,xend=1.E-1)
print('segundo plasmon')
plas1,pq2=xp.Plasmon(q_vec,Potential=lambda x: peq/x,Mermim_option=True,step=1.E-5,xend=1.E-1)
print(len(plas1))
#plt.plot(q_vec,plas1[1],'*')




#plt.plot(q_vec,plas2,'b^')



#qvec=np.linspace(0.0001,0.05,num=50)
#pot=lambda x: 1/x
#pl=x.Plasmon(q_vec=qvec,Potential=pot)
#plt.plot(qvec,pl.real)
#wvec=np.sqrt(0.3*qvec/3.14)
#plt.plot(qvec,wvec,'r')
#plt.plot(x.freq,pl)
# Out:
# (-0.000240430098585-0.14841575143j) -0.144337567297j
# (-0.000240430098585-0.14841575143j)
# segundo plasmon
# 2

# %%
wvec=np.sqrt(mu*q_vec/np.pi*peq)
plt.plot(q_vec/mu,wvec/mu,'r',label='Analytic',linewidth=2.)
#plt.ylim(0.,0.0106)
#plt.xlim(.9E-5,1.1E-5)
plt.plot(q_vec/mu,pq2[0].real/mu,'b--',label='Mermim',linewidth=3.)
#plt.plot(q_vec,plas2[0][0],'b.')
plt.plot(q_vec/mu,plas1[0]/mu,'g.',label='Lindhard')
plt.legend(prop={'size':36},loc=5)
plt.plot(x1,y1,'k',linewidth=2.)
plt.plot(x2,y2,'k',linewidth=2.)
plt.plot(x2,y3,'k',linewidth=2.)
plt.plot(x2,y4,'k',linewidth=2.)
plt.xlim(0,2.051)
plt.ylim(0,2.5)
plt.tick_params(axis='x', labelsize=30)
plt.tick_params(axis='y', labelsize=30)
plt.ylabel(r'$\omega/\omega_F$',fontsize=52)
plt.xlabel(r'$q/k_F$',fontsize=52)

# %%
plt.plot(q_vec,pq2[0].imag)

# %%
mu=0.1
p1=main.sc.grap_parameters(Ef=mu,gamma=1.E-3,lam=0.,m=0.)
qteste=[0.005]
freqteste=[0.005]
xteste=main.Susceptibility(sc.graphene_susc,freqteste,qteste,p1)
mt=xteste.mtest()
qteste2=qteste[0]
freqteste2=freqteste[0]
respteste=mt(qteste2,freqteste2,p1)
print(xteste.susc[0][0]-respteste)
print(xteste.formula(qteste2,freqteste2,p1))

# %%
(-22.625003498903578-6.635230576892361e-07j)*(-22.62500337+113.12499819j)

# %%
susc_formula=xp.mtest()
Potential= lambda x: 1./(x)
q=2.
main.Susceptibility.P_zero([1.,2.],q,Potential,susc_formula,xp.system_parameters)

# %%
p1=main.sc.grap_parameters(Ef=mu,gamma=1.E-3,lam=0.,m=0.)
q=[0.01]
xp=main.Susceptibility(sc.graphene_susc,freq,q,p1)
f=np.linspace(0.0001,0.1,num=500)
xp=main.Susceptibility(sc.graphene_susc,freq,q,p1)
#retorno=main.Susceptibility.P_zero_real(f,q,Potential=lambda xl: 1./xl,susc_formula=xp.mtest(),system_parameters=p1)
retorno=[]
for j in range(len(f)):
     retorno.append(1.-(1./q[0]*xp.mtest()(q[0],f[j],parameters=p1))[0])
retorno=np.asarray(retorno)
plt.plot(f,retorno.real,'*')
plt.plot(f,retorno.imag,'r')
plt.ylim(-0.1,0.1)
